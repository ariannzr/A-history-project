# %% [markdown]
# <a href="https://colab.research.google.com/github/ariannzr/A-history-project/blob/main/Image_processing_setion3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt #baraie visialize kardan dade ha estefade mishe
import xgboost as xgb
import plotly.express as px
import torch
import torch.nn as nn
import torch.nn.functional as F
import skimage #baraie gereftan image
import cv2 #pardazesh tasvir


from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score,precision_score,accuracy_score,recall_score,balanced_accuracy_score
from torch.utils.data import TensorDataset, DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
from torch.optim.lr_scheduler import StepLR

# %%
 image = cv2.imread('/content/drive/MyDrive/ImageProcessing/OpenClose.png')

# %%
plt.imshow(image,cmap='brg' )

# %% [markdown]
# دقت کن که برای تحلیل مرفولوژیکال باید حتما عکس ما باینری باشد  که عکس بالا باینری هست (سیاه و سفید) و اگر باینری نبود باید جز اینکه گری میکنیم یک هم برای بالا و پایین بنویسیم.

# %%
def dilation(img,element_size):
   element = np.ones((element_size,element_size))
   return cv2.dilate(img,element)

def erosion(img,element_size):
   element = np.ones((element_size,element_size))
   return cv2.erode(img,element)

# %%
image_eroded = erosion(image,11)
image_eroded_dilated = dilation(image_eroded,11)
plt.imshow(image_eroded_dilated)

# %%
def open (img ,element):
  img_eroded = cv2.erode(img,element)
  return cv2.dilate(img.element)

def close (img ,element):
  img_eroded = cv2.dilate(img,element)
  return cv2.erode(img.element)

# %%
r=20
element = np.fromfunction(lambda x,y : (x-r)**2 +(y-r)**2 <= r**2 , (2*r+1,2*r+1)).astype('unit8')
img_open = close(image_eroded_dilated,element)
img_open = cv2.(image_eroded_dilated,element)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-3eb9a4001572> in <cell line: 2>()
#       1 r=20
# ----> 2 element = np.fromfunction(lambda x,y : (x-r)**2 +(y-r)**2 <= r**2 , (2*r+1,2*r+1)).astype('unit8')
#       3 img_open = close(image_eroded_dilated,element)
#
# TypeError: data type 'unit8' not understood
